# %% [markdown]
# #introduction to unit catalog

# %%
# %sql
select current_metastore()

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS `databricks_course_ext_dl002`
URL 'abfss://demo@databrickscourseextdl002.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `databricks-course-sc`)
COMMENT 'demo container in external location adls';
